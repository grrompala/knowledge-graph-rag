# %%
# !pip install -r gretriever_requirements.txt

# %%
import argparse
import math
import os
import time

import torch
from dotenv import load_dotenv
from torch_geometric.loader import DataLoader

# from stark_qa import load_qa
from torch import Tensor
from torch.nn.utils import clip_grad_norm_
from torch_geometric import seed_everything
from torch_geometric.nn import GAT, GRetriever
from torch_geometric.nn.nlp import LLM
from tqdm import tqdm

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import os
working_dir='/content/gdrive/MyDrive/knowledge-graph-rag'
os.chdir(working_dir)

# %%
# !export PYTHONPATH=$PYTHONPATH:/content/gdrive/MyDrive/knowledge-graph-rag && \
python '/content/gdrive/MyDrive/knowledge-graph-rag/training/train.py' \
--checkpointing --llama_version tiny_llama --retrieval_config_version 0 \
--algo_config_version 0 --g_retriever_config_version 0 --eval_batch_size 4 --freeze_llm True
# Out:
# Loading stark-qa prime train dataset...
# /content/gdrive/MyDrive/knowledge-graph-rag
# Finished loading train dataset in 8.105196952819824 seconds.
# Loading stark-qa prime val dataset...
# /content/gdrive/MyDrive/knowledge-graph-rag
# Loading stark-qa prime test dataset...
# /content/gdrive/MyDrive/knowledge-graph-rag
# Setting up 'TinyLlama/TinyLlama-1.1B-Chat-v0.1' with configuration: {'revision': 'main', 'max_memory': {0: '14GiB'}, 'low_cpu_mem_usage': True, 'device_map': 'auto', 'torch_dtype': torch.bfloat16}
# config.json: 100% 652/652 [00:00<00:00, 3.88MB/s]
# tokenizer_config.json: 100% 762/762 [00:00<00:00, 5.14MB/s]
# tokenizer.json: 1.84MB [00:00, 59.3MB/s]
# tokenizer.model: 100% 500k/500k [00:00<00:00, 725kB/s]
# added_tokens.json: 100% 21.0/21.0 [00:00<00:00, 103kB/s]
# ...
# special_tokens_map.json: 100% 438/438 [00:00<00:00, 2.52MB/s]
# `torch_dtype` is deprecated! Use `dtype` instead!
# model.safetensors: 100% 4.40G/4.40G [00:54<00:00, 81.4MB/s]
# ...
